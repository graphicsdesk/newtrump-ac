# %%
import pandas as pd

# %%
reviews = pd.DataFrame(pd.read_csv('review.csv', header = None))

# %%
department = pd.DataFrame(pd.read_csv('department.csv', header = None))

# %%
professor = pd.DataFrame(pd.read_csv('professor.csv', header = None))

# %%
reviews = reviews.rename(columns={0:'review_id', 1:'professor_id', 2:'class_review', 3:'ip_address', 4:'workload', 5:'rating', 6:'timestamp'})

# %%
department = department.rename(columns={0:'department_id', 1:'department', 2:'dept_abbrev'})

# %%
professor = professor.rename(columns={0:'professor_id',1:'first_name',2:'last_name',3:'uni',4:'approved',5:'culpa_nuggest_rating'})

# %%
reviews
# Out:
#        review_id  professor_id  \
# 0              5             3
# 1              6             4
# 2              7             4
# 3              8             5
# 4              9             5
# ...          ...           ...
# 28366      85570           776
# 28367      85571           776
# 28368      85572           776
# 28369      85573           776
# 28370      85574           776
#
#                                             class_review ip_address  \
# 0      Thinking about taking this class because you t...        NaN
# 1      D'Altroy has the skill of taking an interestin...        NaN
# 2      Terry D'Altroy is not really a bad professor. ...        NaN
# 3      Since 'Anthrop' does end in 'ology' this class...        NaN
# 4      This monkey class is so awful. Be prepared to ...        NaN
# ...                                                  ...        ...
# 28366                                         ContentOne        NaN
# ...
